# %% [markdown]
# # FOAI Log Explorer
#
# The goal of this notebook is to collect JSON data from the Wayback Machine so that we can create a dataset of JSON for Muckrock's [FOIA Log Explorer](https://www.muckrock.com/foi/logs/), which has pointers to PDF documents in the Wayback Machine.
#
# Each FOIA request also had a detail view in the API. This was used to display a detail page, and critically has the information about documents that were published as a result of the request. These JSON API calls were not collected as part of the initial scraping work, but Internet Archive and Archive Team's work did archive these pages. For example here is the URL for FOIA tracking number `EPA-HQ-2018-006907` is:
#
# https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2018-006907/Request
#
# which has been archived in Wayback Machine:
#
# https://web.archive.org/web/20230926082226/https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2018-006907/Request
#
# In order to fetch these JSON documents we can walk through our list of snapshots that was created in the [Notebook](Notebook.ipynb) looking for these snapshots and then fetch them. Since there can be multiple snapshots of the same URL it can be helpful to ensure we get ones that have a 200 OK response, and prefer the largest response (the most data).

# %%
import re
import pandas

snaps = pandas.read_csv('snapshots.csv.gz', parse_dates=['timestamp'])
snaps = snaps[snaps.status_code == 200]
snaps = snaps[snaps.url.str.match(r'https://foiaonline.gov/foiaonline/api/request/publicRecords/.+/Request', re.IGNORECASE)]
snaps
# Out:
#                         timestamp  \
# 5515667 2023-09-24 03:11:23+00:00
# 5515668 2023-09-24 03:11:33+00:00
# 5515669 2023-09-24 03:11:33+00:00
# 5515670 2023-09-24 03:11:33+00:00
# 5515671 2023-09-24 03:11:36+00:00
# ...                           ...
# 6870355 2023-09-27 20:51:25+00:00
# 6870356 2023-09-27 20:52:10+00:00
# 6870357 2023-09-27 20:52:15+00:00
# 6870358 2023-09-27 20:51:48+00:00
# 6870359 2023-09-27 20:46:06+00:00
#
#                                                                                          url  \
# 5515667  https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2004-000001/Request
# 5515668  https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2007-000001/Request
# 5515669  https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2007-000002/Request
# 5515670  https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2007-000003/Request
# 5515671  https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2007-000004/Request
# ...                                                                                      ...
# 6870355  https://foiaonline.gov/foiaonline/api/request/publicRecords/STB-2023-000113/Request
# 6870356  https://foiaonline.gov/foiaonline/api/request/publicRecords/STB-2023-000114/Request
# 6870357  https://foiaonline.gov/foiaonline/api/request/publicRecords/STB-2023-000115/Request
# 6870358  https://foiaonline.gov/foiaonline/api/request/publicRecords/STB-2023-000116/Request
# 6870359  https://foiaonline.gov/foiaonline/api/request/publicRecords/STB-2023-000117/Request
#
#          status_code         mime_type                            digest  \
# 5515667        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 5515668        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 5515669        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 5515670        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 5515671        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# ...              ...               ...                               ...
# 6870355        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 6870356        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 6870357        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 6870358        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
# 6870359        200.0  application/json  EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM
#
#          length
# 5515667     680
# 5515668     680
# 5515669     683
# 5515670     679
# 5515671     684
# ...         ...
# 6870355     679
# 6870356     680
# 6870357     681
# 6870358     683
# 6870359     680
#
# [1246677 rows x 6 columns]

# %% [markdown]
# ## Multiple Snapshots

# %% [markdown]
# It's interesting to see how many snapshots of the same URL, in roughly the same amount of time yielded different results:

# %%
pandas.set_option('display.max_colwidth', None)

snaps[snaps.url == 'https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request']
# Out:
#                         timestamp  \
# 6662416 2023-09-25 20:27:58+00:00
# 6662417 2023-09-25 20:28:25+00:00
# 6662418 2023-09-25 20:29:00+00:00
# 6662419 2023-09-25 20:30:00+00:00
# 6662420 2023-09-25 20:31:20+00:00
# ...                           ...
# 6662538 2023-09-25 21:53:35+00:00
# 6662539 2023-09-25 21:54:20+00:00
# 6662540 2023-09-25 21:54:43+00:00
# 6662541 2023-09-25 21:55:14+00:00
# 6662542 2023-09-25 21:55:38+00:00
#
#                                                                                             url  \
# 6662416  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662417  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662418  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662419  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662420  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# ...                                                                                         ...
# 6662538  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662539  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662540  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662541  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
# 6662542  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
#
#          status_code         mime_type                            digest  \
# 6662416        200.0  application/json  4S4KLZF7HZTO57LIE64EBFK5IOTJFO6Y
# 6662417        200.0  application/json  POE23XF7X6KMPNMGQS7XLMESXLF5Y7QF
# 6662418        200.0  application/json  R2LH2BKFE6SES6XPR74NEDLMP3ZMXVNU
# 6662419        200.0  application/json  QMK3WEQPJWJ2DII77F4BE5NIE5GPHOYA
# 6662420        200.0  application/json  TD6VFY7YY5H5HJXX5P3IWO35S34KPB25
# ...              ...               ...                               ...
# 6662538        200.0  application/json  MIIA6ZU34UX3E2Y77THQB27XV27J7J5F
# 6662539        200.0  application/json  WLS5GO3Y5ARFERU3J3WE3KE2QIUZSAIH
# 6662540        200.0  application/json  2PTRSCT7E43RXUVEMMJJQB3SEVWWFEDI
# 6662541        200.0  application/json  2AIP2H62MD6NW47QGNGWJCV5S57K62MV
# 6662542        200.0  application/json  ANZPVLMD5ODOQK4RW4WOLEP4LOXDK6ID
#
#          length
# 6662416    3945
# 6662417    3861
# 6662418    3832
# 6662419    4090
# 6662420    3878
# ...         ...
# 6662538    3783
# 6662539    3641
# 6662540    3841
# 6662541    2702
# 6662542     689
#
# [127 rows x 6 columns]

# %% [markdown]
# You can see the varying JSON responses here:
#
# https://web.archive.org/web/20230000000000*/https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request

# %% [markdown]
# So it is helpful to prefer the response with the largest response (the most data). This can be returned by ordering all the snapshots by their length, grouping by URL, and fetching the first one.

# %%
snaps = snaps.sort_values('length', ascending=False)
snaps = snaps.groupby('url').agg(lambda row: row.iloc[0]).reset_index()

# %% [markdown]
# Now we can see that we only have one row for that URL, and it is the largest one (4119 bytes).

# %%
snaps[snaps.url == 'https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request']
# Out:
#                                                                                             url  \
# 1071550  https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request
#
#                         timestamp         mime_type  \
# 1071550 2023-09-25 21:35:00+00:00  application/json
#
#                                    digest  length
# 1071550  R5IMZMLOAVE2ENCELX7DRXVBVPE3JI6J    4119

# %% [markdown]
# ## Duplicate Responses
#
# One interesting thing about the API responses is that it's possible to see from the Wayback API's *digest* value that many of them are identical. So rather than requesting these many times, we can keep a cache on disk, and use that instead.

# %%
snaps.digest.value_counts()
# Out:
# digest
# EAQDUJQCZOPLHJSCV2KAIQ3ILBVONSVM    1114674
# WMCJY4Q7IGOVNP4C227AFW5JBJCFCIY2        174
# ZSFEE774XFVXNFO2OU5A5V3T4UXDYHTH        147
# VRSBAJNTXSRBP4NI5VRXFDPGEBEOZP5S         62
# LNLEPICX5XOTFKK7NUXJFGD3AYJ4AD5X         50
#                                      ...
# HEI5UI3XLTMH3BNIRQX46M2XCMY2HWCE          1
# CRM2LJD46L3464I5PKQFCWL3L7EFTM7R          1
# FB5SVIREUTRHGJDGCCARCGLYNBK3Q3I6          1
# HU453HXYEUVW7TZXWZ3RR5B4VTU2NELO          1
# MLOCH4VWWC6DG6F2KKBT2AT56VZSOBN3          1
# Name: count, Length: 65641, dtype: int64

# %% [markdown]
# So when we fetch the responses it can be helpful if we don't issue requests to the API for responses we've already received. This can cut down on the time it takes to collect them. One way of achieving this is to create a disk cache to store the responses using the digest value as a key.

# %% [markdown]
# ## Collect the Data
#
# Now it's time to collect the publicRecords JSON data. We'll start by creating a cache for the responses.

# %%
import dbm

cache = dbm.open('cache', 'c')

# %% [markdown]
# And a function that looks up the snapshot.

# %%
import json
import time
import requests

http = requests.Session()
def get_response(row, sleep=0):
    # if we already know what the JSON is, return it
    if row.digest in cache:
        return json.loads(cache[row.digest])

    if sleep > 0:
        time.sleep(sleep)

    # fetch the data
    t = row.timestamp.strftime('%Y%m%d%H%M%S')
    wb_url = f'https://web.archive.org/web/{t}id_/{row.url}'

    # guard against malformed JSON coming back from Wayback Machine
    try:
        data = http.get(wb_url).json()
        cache[row.digest] = json.dumps(data)
        return data
    except json.JSONDecodeError:
        cache[row.digest] = '{}'
        return {}

# %% [markdown]
# Now we can try out the function with the row for `EPA-HQ-2017-001504` which was examined above. For comparison the Wayback URL should be: https://web.archive.org/web/20230925213500id_/https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request

# %%
print(json.dumps(get_response(snaps[snaps.url == 'https://foiaonline.gov/foiaonline/api/request/publicRecords/EPA-HQ-2017-001504/Request'].iloc[0]), indent=2))
# Out:
# {
#   "draw": 93,
#   "recordsTotal": 99999,
#   "recordsFiltered": 99999,
#   "data": [
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Williams Ignacio Gas Plant 12_1_15 114 letter",
#       "fileName": "Williams Ignacio Gas Plant 12_1_15 114 letter.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Scott Patefield",
#       "uploadedByEmail": "patefield.scott@epa.gov",
#       "createdDate": "03/22/2017 09:34 AM",
#       "lastModifiedDate": "04/30/2019 12:25 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "2d6a4bcd-5eb4-471f-a687-dce963ace8af",
#       "size": "0.2543",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "21255e2a-9b8c-4dbd-8c6f-5a733b175bfc",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Parker Hannifin Corp. 308 Ltr",
#       "fileName": "Parker Hannifin Corp. 308 Ltr. 12022015.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Leonard Dangerfield",
#       "uploadedByEmail": "Dangerfield.Leonard@epa.gov",
#       "createdDate": "03/29/2017 12:06 PM",
#       "lastModifiedDate": "04/26/2019 02:30 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "34421314-9875-49ba-87dd-308710301859",
#       "size": "0.2785",
#       "recordReleaseDate": "10/23/2017 12:01 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "daaef39c-fc10-41ce-8b0a-50e8ad6ae242",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "R1 - J Goodison CAA 114 RR  January 2014",
#       "fileName": "R1 - J Goodison CAA 114 RR  January 2014.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "NOVs",
#       "uploadedBy": "Cristeen Schena",
#       "uploadedByEmail": "schena.cristeen@epa.gov",
#       "createdDate": "03/28/2017 07:57 AM",
#       "lastModifiedDate": "05/28/2019 10:59 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "8153159e-5bcb-457f-9efc-7770bf89c0d2",
#       "size": "1.7833",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "a9b81077-3324-4dcf-b220-5c43003e4c8f",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "ltr L Farnsworth fr D Breffle re Notice of Violation 11-7-14",
#       "fileName": "ltr L Farnsworth fr D Breffle re Notice of Violation 11-7-14.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "EPA,Region 8,UIC,SDWA 300h-2",
#       "uploadedBy": "Gary Wang",
#       "uploadedByEmail": "wang.gary@epa.gov",
#       "createdDate": "03/29/2017 04:30 PM",
#       "lastModifiedDate": "05/02/2019 05:15 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "6fec1588-d47e-4448-a4d4-14993554caff",
#       "size": "0.1273",
#       "recordReleaseDate": "03/30/2017 01:26 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "b395b49a-4224-4555-93b8-d971b63a8974",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "06.14",
#       "fileName": "06.14.2016_PAS000430447.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Tanya Lewis",
#       "uploadedByEmail": "Lewis.tanya@Epa.gov",
#       "createdDate": "04/14/2017 12:22 PM",
#       "lastModifiedDate": "01/20/2019 03:17 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "9dace6b8-5c36-4617-bbe8-940acf5f671a",
#       "size": "0.2902",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "19fc1549-5eab-4c6d-865c-7fc49d8fbdca",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "SDWA-UIC-IR-16-036 - CozyCorp79-WorkOfArt",
#       "fileName": "SDWA-UIC-IR-16-036 - CozyCorp79-WorkOfArt.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Wanda Calderon",
#       "uploadedByEmail": "Calderon.Wanda@epa.gov",
#       "createdDate": "04/26/2017 10:17 AM",
#       "lastModifiedDate": "05/01/2019 11:49 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "11046a2c-2182-40a9-8cfd-aff96bc4cd46",
#       "size": "1.1375",
#       "recordReleaseDate": "05/24/2017 11:03 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "0e906320-badb-42e5-8ae6-0092dbded1a7",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Region 5-ARD Wisconsin (1)",
#       "fileName": "Region 5 ARD-WI Migrated Combined.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "ARD R5 Upload,Branch and Section Chief do not contain exempt",
#       "uploadedBy": "Eric Cederholm",
#       "uploadedByEmail": "cederholm.eric@epa.gov",
#       "createdDate": "04/03/2017 12:37 PM",
#       "lastModifiedDate": "12/28/2018 02:26 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "a6ae2b4b-1b25-438d-a7da-12b6393e8470",
#       "size": "17.8193",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "2d75fb21-24a3-417e-958b-e2acbeb1a1bf",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "NuStar Pipeline Operating P.LOW",
#       "fileName": "NuStar Pipeline Operating P.LOW.07212016.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Cynthia Sehnert-Jones",
#       "uploadedByEmail": "Sehnert-Jones.Cynthia@epa.gov",
#       "createdDate": "04/13/2017 03:09 PM",
#       "lastModifiedDate": "01/29/2019 03:54 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "35355dc4-7581-4e0e-990d-b5694438ac62",
#       "size": "0.174",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "c61e0cfe-d604-4fc0-9440-2af5ccce5af0",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "ltr Kerry Smith fr D Breffle re Notice of Violation 05-16-14",
#       "fileName": "ltr Kerry Smith fr D Breffle re Notice of Violation 05-16-14.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "EPA,Region 8,UIC,SDWA 300h-2",
#       "uploadedBy": "Gary Wang",
#       "uploadedByEmail": "wang.gary@epa.gov",
#       "createdDate": "03/29/2017 04:30 PM",
#       "lastModifiedDate": "05/02/2019 05:15 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "6fec1588-d47e-4448-a4d4-14993554caff",
#       "size": "0.1901",
#       "recordReleaseDate": "03/30/2017 01:26 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "bb25db12-441f-49da-8527-f21475cac5dd",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Carleton Life Support Systems LOW 03182014",
#       "fileName": "Carleton Life Support Systems LOW 03182014.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Cynthia Sehnert-Jones",
#       "uploadedByEmail": "Sehnert-Jones.Cynthia@epa.gov",
#       "createdDate": "04/13/2017 03:09 PM",
#       "lastModifiedDate": "01/29/2019 03:54 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "35355dc4-7581-4e0e-990d-b5694438ac62",
#       "size": "0.1529",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "4963c203-5557-4435-87c2-b958a834dfb4",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "R1 - CT - Jeliff Wire Products 12 08 14",
#       "fileName": "R1 - CT - Jeliff Wire Products 12 08 14.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "NOVs",
#       "uploadedBy": "Cristeen Schena",
#       "uploadedByEmail": "schena.cristeen@epa.gov",
#       "createdDate": "03/28/2017 07:53 AM",
#       "lastModifiedDate": "05/28/2019 10:59 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "8153159e-5bcb-457f-9efc-7770bf89c0d2",
#       "size": "0.1566",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "8ee53224-6143-4206-a265-9fb60d3d1314",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Croda G",
#       "fileName": "Croda G.Supplee 1_14_2015.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "EPA-HQ-2017-001504,EIP SC NRDC EJ FOIA 11/21/16",
#       "uploadedBy": "Dorothea Brown",
#       "uploadedByEmail": "brown.dorothea@epa.gov",
#       "createdDate": "03/13/2017 01:38 PM",
#       "lastModifiedDate": "01/19/2019 02:31 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "4547cf88-9483-478a-97d0-247afb9255a8",
#       "size": "0.5623",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "61eaf22d-b4d5-469d-bb98-36257840c327",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "CWA-IR-16-017 & CEI_NJP000147_2016-04-19_Township of Little Falls",
#       "fileName": "CWA-IR-16-017 & CEI_NJP000147_2016-04-19_Township of Little Falls.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Wanda Calderon",
#       "uploadedByEmail": "Calderon.Wanda@epa.gov",
#       "createdDate": "04/26/2017 10:06 AM",
#       "lastModifiedDate": "05/01/2019 11:49 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "11046a2c-2182-40a9-8cfd-aff96bc4cd46",
#       "size": "6.8737",
#       "recordReleaseDate": "05/24/2017 11:03 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "ee4c330f-ebef-4d30-b6dc-b175b5c14e0a",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "ltr B Lane fr D Breffle re Notice of Violation 2-1-16",
#       "fileName": "ltr B Lane fr D Breffle re Notice of Violation 2-1-16.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "EPA,Region 8,UIC,SDWA 300h-2",
#       "uploadedBy": "Gary Wang",
#       "uploadedByEmail": "wang.gary@epa.gov",
#       "createdDate": "03/29/2017 04:30 PM",
#       "lastModifiedDate": "05/02/2019 05:15 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "6fec1588-d47e-4448-a4d4-14993554caff",
#       "size": "0.1076",
#       "recordReleaseDate": "03/30/2017 01:26 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "bdbe3363-a9af-480d-a996-1a89ea5a5daf",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Picayune Rancheria NPDES 308 Request 2015-4-28",
#       "fileName": "Picayune Rancheria NPDES 308 Request 2015-4-28.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "ENF 3-1 Responsive Records",
#       "uploadedBy": "Carol Sachs",
#       "uploadedByEmail": "sachs.carol@epa.gov",
#       "createdDate": "04/07/2017 03:04 PM",
#       "lastModifiedDate": "01/31/2019 02:07 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "e42cc95c-4bb7-4b38-8350-695171b3e4cb",
#       "size": "0.5026",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "3ba0bca7-61b6-4ac8-8fb1-eabb78cb5310",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "2016-08-12_308_BP Spring Creek G1",
#       "fileName": "2016-08-12_308_BP Spring Creek G1.PDF",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Stephanie Dejong",
#       "uploadedByEmail": "dejong.stephanie@epa.gov",
#       "createdDate": "03/08/2017 05:39 PM",
#       "lastModifiedDate": "03/31/2019 02:31 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "400cf5d8-7e44-4cd9-a212-5db33dce7812",
#       "size": "0.8546",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "e1eaf682-3598-4388-b49b-5876c3c4d53a",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Van Sickle Distribution Center Letter of Warning.06.30",
#       "fileName": "Van Sickle Distribution Center Letter of Warning.06.30.2015.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Cynthia Sehnert-Jones",
#       "uploadedByEmail": "Sehnert-Jones.Cynthia@epa.gov",
#       "createdDate": "04/13/2017 03:09 PM",
#       "lastModifiedDate": "01/29/2019 03:54 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "35355dc4-7581-4e0e-990d-b5694438ac62",
#       "size": "0.0666",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "7f658ca3-41b7-4404-b8df-c55108a03206",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Bergquist 4 15 2015",
#       "fileName": "Bergquist 4 15 2015.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "R5 RCRA NOVs and IR Jan 2014 to April 2017",
#       "uploadedBy": "Thomas Crosetto",
#       "uploadedByEmail": "Crosetto.Thomas@epa.gov",
#       "createdDate": "05/15/2017 07:19 PM",
#       "lastModifiedDate": "03/26/2019 09:20 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "3ffda15c-c932-4349-8637-e3390239686c",
#       "size": "0.3612",
#       "recordReleaseDate": "05/24/2017 11:03 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "b93b30e3-e02b-4883-968b-cade7eb8d4ba",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Sonneborn Letter",
#       "fileName": "Sonneborn Letter.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Larry Johnson",
#       "uploadedByEmail": "Johnson.larry-C@Epa.gov",
#       "createdDate": "04/24/2017 04:05 PM",
#       "lastModifiedDate": "04/15/2019 07:54 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "f452681f-23a7-4488-a804-54fb5fe6ac39",
#       "size": "0.7719",
#       "recordReleaseDate": "05/24/2017 11:03 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "a3524022-acfe-426a-8cd3-936130c9ad55",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "OBS NOV Signed 10.28",
#       "fileName": "OBS NOV Signed 10.28.14.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Brian Levo",
#       "uploadedByEmail": "Levo.Brian@epa.gov",
#       "createdDate": "03/24/2017 04:59 PM",
#       "lastModifiedDate": "04/06/2019 02:26 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "7d915e77-f3a0-4824-b32f-12abe58b2d55",
#       "size": "0.2395",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "f6f120b1-6d06-4174-9f57-3ef69d3544f4",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "CWA-IR-16-026_NYR20A122_2016-06-24_Town of Amherst",
#       "fileName": "CWA-IR-16-026_NYR20A122_2016-06-24_Town of Amherst.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Wanda Calderon",
#       "uploadedByEmail": "Calderon.Wanda@epa.gov",
#       "createdDate": "04/26/2017 10:06 AM",
#       "lastModifiedDate": "05/01/2019 11:49 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "11046a2c-2182-40a9-8cfd-aff96bc4cd46",
#       "size": "2.5843",
#       "recordReleaseDate": "05/24/2017 11:03 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "d0e44879-30ee-4218-8bc7-bb6e55d459a8",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Dupont Fabros 114 Information Request",
#       "fileName": "Dupont Fabros 114 Information Request.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "EPA-HQ-2017-001504,EIP SC NRDC EJ FOIA 11/21/16",
#       "uploadedBy": "Dorothea Brown",
#       "uploadedByEmail": "brown.dorothea@epa.gov",
#       "createdDate": "03/13/2017 01:38 PM",
#       "lastModifiedDate": "01/19/2019 02:31 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "4547cf88-9483-478a-97d0-247afb9255a8",
#       "size": "2.741",
#       "recordReleaseDate": "03/28/2017 02:13 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "d24de31d-a8d6-4a95-9811-8e7dfebf04c7",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Cloyes Gear and Products 308 Info Request",
#       "fileName": "Cloyes Gear and Products 308 Info Request.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "James Coleman",
#       "uploadedByEmail": "coleman.james@epa.gov",
#       "createdDate": "04/17/2017 06:16 PM",
#       "lastModifiedDate": "12/28/2018 02:26 AM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "dcf97f32-9847-40b8-917f-26d0f733a8a9",
#       "size": "0.4577",
#       "recordReleaseDate": "04/24/2017 10:17 AM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "a9feb254-16ec-42ba-aa0b-065c06f67411",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "Woodbine PWS",
#       "fileName": "Woodbine PWS.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": null,
#       "uploadedBy": "Angela Acord",
#       "uploadedByEmail": "acord.angela@epa.gov",
#       "createdDate": "04/11/2017 11:52 AM",
#       "lastModifiedDate": "01/28/2019 12:42 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "bdea5130-3530-472f-9a56-96a3a946ad0a",
#       "size": "0.0801",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "a2d9370d-3a7b-4253-814e-23232581d783",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     },
#     {
#       "trackingNumber": "EPA-HQ-2017-001504",
#       "title": "2017-01-17_EPA Notice of Violation to Derive Entities",
#       "fileName": "2017-01-17_EPA Notice of Violation to Derive Entities.pdf",
#       "releaseType": "UR - Unredacted - Releasable to the General Public",
#       "exemptions": null,
#       "ex3statutes": [
#         "N/A"
#       ],
#       "ex5subtypes": [
#         "N/A"
#       ],
#       "keywords": "ENF 2-1 Responsive Records",
#       "uploadedBy": "Carol Sachs",
#       "uploadedByEmail": "sachs.carol@epa.gov",
#       "createdDate": "04/07/2017 02:57 PM",
#       "lastModifiedDate": "01/31/2019 02:07 PM",
#       "fileType": "Adobe PDF Document",
#       "fileFormat": null,
#       "author": null,
#       "addedBy": "e42cc95c-4bb7-4b38-8350-695171b3e4cb",
#       "size": "7.7397",
#       "recordReleaseDate": "04/19/2017 03:31 PM",
#       "retentionPeriod": "6 year",
#       "frequentlyRequested": null,
#       "type": "Record",
#       "recordId": "e515de50-efd6-489d-83f8-c8105d396439",
#       "referredToNonparticipatingAgency": "No",
#       "referredFromOtherAgency": "No",
#       "referredType": null,
#       "recordType": null,
#       "taskId": null,
#       "isPlaceholder": false
#     }
#   ],
#   "dataMap": null
# }

# %% [markdown]
# Now we are ready to fetch the data! We can write each response to a JSONL file, after ensuring that the data has the `trackingNumber` in it (it only seems to be present when there are items in the `data` list). It's also helpful to put a little sleep in there to not go too fast and potentially get blocked by Internet Archive.

# %%
import re
import time
import gzip
from tqdm.notebook import tqdm

output = open('full_requests.jsonl', 'w')

for i, row in tqdm(snaps.iterrows(), total=len(snaps)):
    data = get_response(row, sleep=.5)
    # data can be the empty dict in situations where there was invalid JSON in the response
    if len(data) > 0:
        data['trackingNumber'] = re.search('publicRecords/(.+)/Request$', row.url, re.IGNORECASE).group(1)
        output.write(json.dumps(data) + "\n")
# Out:
#   0%|          | 0/1180808 [00:00<?, ?it/s]

# %% [markdown]
# ## Analysis
#
# So how many responses had data for documents?

# %%
count = data_count = doc_count = 0
for line in gzip.open('full_requests.jsonl.gz', 'rt'):
    count += 1
    request = json.loads(line)
    if len(request['data']) > 0:
        data_count += 1
        doc_count += len(request['data'])

print(f"total responses: {count} ; total with documents: {data_count} ; total documents: {doc_count}")
# Out:
# total responses: 1180636 ; total with documents: 65604 ; total documents: 320432

# %% [markdown]
# Why are there so few document details in the data we received?
#
# One odd thing I noticed when inspecting the initial metadata for each request is that there appear to be a requests that had a disposition of full or partial grant, which didn't appear to have any documents associated with them online, at least at the time of archiving.
#
# For example notice how there are no documents listed in the "Released Records" section for `CBP-2009-016175` even though it was partially granted?
#
# https://web.archive.org/web/20230924035834/https://foiaonline.gov/foiaonline/action/public/submissionDetails?trackingNumber=CBP-2009-016175&type=Request
#
# And as we would expect to see, the API response for `CBP-2009-016165` appears to have no documents
#
# https://web.archive.org/web/20230924035835/https://foiaonline.gov/foiaonline/api/request/publicRecords/CBP-2009-016175/Request
#
# The same is true for `DON-NAVY-2020-000182` which was a "Full Grant" request:
#
# https://web.archive.org/web/20230926182344/https://foiaonline.gov/foiaonline/action/public/submissionDetails?trackingNumber=DON-NAVY-2020-000182&type=Request

# %% [markdown]
# We can use the initial set of metadata collected in [Notebook](Notebook.ipynb) to see how many fully or partially granted requests there are:

# %%
requests = pandas.read_json('data.jsonl.gz', lines=True)

# %%
requests.finalDisposition.value_counts()
# Out:
# finalDisposition
# Partial Grant/Partial Denial                        369269
# No Records                                          342133
# Full Grant                                          184066
# Improper FOIA Request for Other Reasons             111055
# Not an Agency Record                                 42699
# Duplicate Request                                    31664
# Request Withdrawn                                    24905
# Records Not Reasonably Described                     12636
# Full Denial Based on Exemptions                      11655
# Completely Reversed/Remanded                         11512
# Other                                                 9614
# All Records Referred to Another Agency                9440
# Affirmed on Appeal                                    8162
# Closed for Other Reasons                              6194
# Partially Affirmed & Partially Reversed/Remanded      4064
# Fee-Related Reason                                    3150
# Name: count, dtype: int64

# %%
granted = requests[requests.finalDisposition.isin(['Full Grant', 'Partial Grant/Partial Denial'])]
len(granted)
# Out:
# 553335

# %%
## Archived PDFs

How many archived FOIAOnline PDFs are there in the Wayback Machine?
# Out:
# Object `Machine` not found.

# %%
all_snaps = pandas.read_csv('snapshots.csv.gz')
pdf_snaps = all_snaps[all_snaps.url.str.match(r'.*foiaonline/api/request/downloadFile/.*')]
pdf_snaps
# Out:
#                          timestamp  \
# 3686159  2023-09-25 10:56:09+00:00
# 3686160  2023-09-30 06:17:37+00:00
# 3686161  2023-09-25 23:06:41+00:00
# 3686162  2023-09-25 22:44:19+00:00
# 3686163  2023-09-26 20:32:37+00:00
# ...                            ...
# 5491403  2023-09-24 12:10:16+00:00
# 5491404  2023-09-24 17:53:01+00:00
# 5491405  2023-09-24 12:10:56+00:00
# 5491406  2023-09-24 12:09:15+00:00
# 5491407  2023-09-25 06:41:48+00:00
#
#                                                                                                                                                                                                                   url  \
# 3686159  https://foiaonline.gov/foiaonline/api/request/downloadFile/!!totals-joe%20did%20this%20because%20PA%20too%20lazy.xlsx/ce720261-c0e0-4987-aed0-160b21828462?x-csrf-token=5816939a-41bd-438e-aa2f-94751b82c85b
# 3686160     https://foiaonline.gov/foiaonline/api/request/downloadFile/!%2020150225_Index%20of%20Manifest%20Collection%20B.pdf/a503656e-f029-42df-bfe9-10ec123511eb?x-csrf-token=cf96dfcc-e4a2-4a62-ae29-394a9e024cd4
# 3686161                    https://foiaonline.gov/foiaonline/api/request/downloadFile/!20170228_Sewer_Asbuilt_ToSRC%20(1).xlsx/a69fb996-9152-4089-921d-45a7adba5dc8?x-csrf-token=da32e734-23e8-431f-96c7-c5d3b59dcb1c
# 3686162                          https://foiaonline.gov/foiaonline/api/request/downloadFile/!20170228_Sewer_Asbuilt_ToSRC.xlsx/e7d90f47-786c-4860-910f-41329602057d?x-csrf-token=da32e734-23e8-431f-96c7-c5d3b59dcb1c
# 3686163                                    https://foiaonline.gov/foiaonline/api/request/downloadFile/!FilesIndex_5_6_2019.pdf/cb3dbea2-4c77-46d4-927f-bdc89db2e55b?x-csrf-token=b997b043-77e4-462f-bf30-f78a1a606d63
# ...                                                                                                                                                                                                               ...
# 5491403                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web8272_h.pdf/59be36d5-29c1-4da9-8eb1-2ab82c1f6fe9?x-csrf-token=0477a5ec-66f8-4292-9472-43147ed09fc3
# 5491404                                                  https://foiaonline.gov/foiaonline/api/request/downloadFile/~web87.pdf/1e1bb4d9-ca7a-40dd-b3ca-0ffc0112c6b0?x-csrf-token=b51856db-e301-4214-9828-9f996a6059ae
# 5491405                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web8808_h.pdf/a07bcbb6-9c0e-4753-9cb6-0b62ba0843fa?x-csrf-token=0477a5ec-66f8-4292-9472-43147ed09fc3
# 5491406                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web9324_h.pdf/7d7a0524-6c07-4ef7-a044-6baab88f80da?x-csrf-token=0477a5ec-66f8-4292-9472-43147ed09fc3
# 5491407                                                https://foiaonline.gov/foiaonline/api/request/downloadFile/~WRL3383.tmp/f44e1096-9fe7-4954-ba72-8cc4c67bb57c?x-csrf-token=67d51cc0-41cb-410f-bf17-08faf4c14f5e
#
#          status_code                 mime_type  \
# 3686159        200.0  application/octet-stream
# 3686160        200.0  application/octet-stream
# 3686161          NaN              warc/revisit
# 3686162        200.0  application/octet-stream
# 3686163        200.0  application/octet-stream
# ...              ...                       ...
# 5491403        200.0  application/octet-stream
# 5491404        200.0  application/octet-stream
# 5491405        200.0  application/octet-stream
# 5491406        200.0  application/octet-stream
# 5491407        200.0  application/octet-stream
#
#                                    digest  length
# 3686159  QRBEDCSKJ257YOW7L3AQBP4EFDWYAKZQ   13701
# 3686160  ILS5DSVQRQNM4AABKL5TEDTCZ73ZFSVN   75976
# 3686161  5FWDJGLFCVXIOZOQ46G4WI5MUUP5FCF5     917
# 3686162  5FWDJGLFCVXIOZOQ46G4WI5MUUP5FCF5   15824
# 3686163  OL5NQUXHN7LBPIOOV2BTBZPNM6LS2XH4   77723
# ...                                   ...     ...
# 5491403  TZI3Z52KGNLIM6RSYVZ6E6CRO3VVNRH7   47259
# 5491404  BPMHEL6OUDYVUHTQPOSJMK3SNRBYY2HF   98558
# 5491405  U7BX7SQRR53QTSIPVPJCARKQ2XZ2XWXP   37998
# 5491406  JJJJMG6RL7Z4UCFBIU7MU5XXTCPZY7TH   46414
# 5491407  KFYYYPC56E2YQYUYRYWRBQOX36NWJG6G    9754
#
# [1805249 rows x 6 columns]

# %%
from urllib.parse import urlparse

def strip_token(url):
    uri = urlparse(url)
    return f"{uri.scheme}://{uri.netloc}{uri.path}"

strip_token('https://foiaonline.gov/foiaonline/api/request/downloadFile/~WRL3383.tmp/f44e1096-9fe7-4954-ba72-8cc4c67bb57c?x-csrf-token=67d51cc0-41cb-410f-bf17-08faf4c14f5e')
# Out:
# 'https://foiaonline.gov/foiaonline/api/request/downloadFile/~WRL3383.tmp/f44e1096-9fe7-4954-ba72-8cc4c67bb57c'

# %%
pdf_snaps.url = pdf_snaps.url.map(strip_token)
pdf_snaps
# Out:
# /var/folders/9g/t4bgvmr566190l4nl87nrtkh0000gs/T/ipykernel_22428/3680254798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdf_snaps.url = pdf_snaps.url.map(strip_token)
#                          timestamp  \
# 3686159  2023-09-25 10:56:09+00:00
# 3686160  2023-09-30 06:17:37+00:00
# 3686161  2023-09-25 23:06:41+00:00
# 3686162  2023-09-25 22:44:19+00:00
# 3686163  2023-09-26 20:32:37+00:00
# ...                            ...
# 5491403  2023-09-24 12:10:16+00:00
# 5491404  2023-09-24 17:53:01+00:00
# 5491405  2023-09-24 12:10:56+00:00
# 5491406  2023-09-24 12:09:15+00:00
# 5491407  2023-09-25 06:41:48+00:00
#
#                                                                                                                                                                 url  \
# 3686159  https://foiaonline.gov/foiaonline/api/request/downloadFile/!!totals-joe%20did%20this%20because%20PA%20too%20lazy.xlsx/ce720261-c0e0-4987-aed0-160b21828462
# 3686160     https://foiaonline.gov/foiaonline/api/request/downloadFile/!%2020150225_Index%20of%20Manifest%20Collection%20B.pdf/a503656e-f029-42df-bfe9-10ec123511eb
# 3686161                    https://foiaonline.gov/foiaonline/api/request/downloadFile/!20170228_Sewer_Asbuilt_ToSRC%20(1).xlsx/a69fb996-9152-4089-921d-45a7adba5dc8
# 3686162                          https://foiaonline.gov/foiaonline/api/request/downloadFile/!20170228_Sewer_Asbuilt_ToSRC.xlsx/e7d90f47-786c-4860-910f-41329602057d
# 3686163                                    https://foiaonline.gov/foiaonline/api/request/downloadFile/!FilesIndex_5_6_2019.pdf/cb3dbea2-4c77-46d4-927f-bdc89db2e55b
# ...                                                                                                                                                             ...
# 5491403                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web8272_h.pdf/59be36d5-29c1-4da9-8eb1-2ab82c1f6fe9
# 5491404                                                  https://foiaonline.gov/foiaonline/api/request/downloadFile/~web87.pdf/1e1bb4d9-ca7a-40dd-b3ca-0ffc0112c6b0
# 5491405                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web8808_h.pdf/a07bcbb6-9c0e-4753-9cb6-0b62ba0843fa
# 5491406                                              https://foiaonline.gov/foiaonline/api/request/downloadFile/~web9324_h.pdf/7d7a0524-6c07-4ef7-a044-6baab88f80da
# 5491407                                                https://foiaonline.gov/foiaonline/api/request/downloadFile/~WRL3383.tmp/f44e1096-9fe7-4954-ba72-8cc4c67bb57c
#
#          status_code                 mime_type  \
# 3686159        200.0  application/octet-stream
# 3686160        200.0  application/octet-stream
# 3686161          NaN              warc/revisit
# 3686162        200.0  application/octet-stream
# 3686163        200.0  application/octet-stream
# ...              ...                       ...
# 5491403        200.0  application/octet-stream
# 5491404        200.0  application/octet-stream
# 5491405        200.0  application/octet-stream
# 5491406        200.0  application/octet-stream
# 5491407        200.0  application/octet-stream
#
#                                    digest  length
# 3686159  QRBEDCSKJ257YOW7L3AQBP4EFDWYAKZQ   13701
# 3686160  ILS5DSVQRQNM4AABKL5TEDTCZ73ZFSVN   75976
# 3686161  5FWDJGLFCVXIOZOQ46G4WI5MUUP5FCF5     917
# 3686162  5FWDJGLFCVXIOZOQ46G4WI5MUUP5FCF5   15824
# 3686163  OL5NQUXHN7LBPIOOV2BTBZPNM6LS2XH4   77723
# ...                                   ...     ...
# 5491403  TZI3Z52KGNLIM6RSYVZ6E6CRO3VVNRH7   47259
# 5491404  BPMHEL6OUDYVUHTQPOSJMK3SNRBYY2HF   98558
# 5491405  U7BX7SQRR53QTSIPVPJCARKQ2XZ2XWXP   37998
# 5491406  JJJJMG6RL7Z4UCFBIU7MU5XXTCPZY7TH   46414
# 5491407  KFYYYPC56E2YQYUYRYWRBQOX36NWJG6G    9754
#
# [1805249 rows x 6 columns]

# %%
len(pdf_snaps.url.unique())
# Out:
# 1551866

# %% [markdown]
# We only have references to 320,432 of them.
